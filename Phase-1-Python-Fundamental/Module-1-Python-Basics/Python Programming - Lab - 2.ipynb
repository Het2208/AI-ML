# %% [markdown]
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 2</b></center>
# <center><b><h1>Roll No : 521</b></center>
# <center><b><h1>Name : Het Kanasagara</b></center>
# <pre>

# %% [markdown]
# ### 01) WAP to print “Hello World..!!”

# %%
print("Hello World..!!")
# Out:
# Hello World..!!

# %% [markdown]
# ### 02) WAP to accept your name and display a welcome message.
# #### Input: Priya
# #### Output: Hello Priya, welcome to Python Lab.

# %%
name = input("Enter you name : ")
print(f"Hello {name}, welcome to Python Lab.")
# Out:
# Enter you name :  Het
# Hello Het, welcome to Python Lab.

# %% [markdown]
# ### 03) WAP to accept three integers and display the numbers, their sum, and average.
# #### Input: 10 20 30
# #### Output:
# ##### Numbers: 10 20 30
# ##### Sum: 60
# ##### Average: 20.0

# %%
num1 = int(input("Enter a number 1 :"))
num2 = int(input("Enter a number 2 :"))
num3 = int(input("Enter a number 3 :"))
sum = num1+num2+num3
avg = sum/3

print(f"Numbers : {num1} {num2} {num3}")
print(f"Sum : {sum}")
print(f"Average : {avg}")
# Out:
# Enter a number 1 : 10
# Enter a number 2 : 20
# Enter a number 3 : 30
# Numbers : 10 20 30
# Sum : 60
# Average : 20.0

# %% [markdown]
# ### 04) WAP to accept name (string), age (int), and percentage (float).
# #### Input : Riya,18,92.5
# #### Output :
# ##### Name: Riya  Type: <class 'str'>
# ##### Age: 18  Type: <class 'int'>
# ##### Percentage: 92.5  Type: <class 'float'>

# %%
name = input("Enter your name : ")
age = int(input("Enter your age : "))
per = float(input("Enter your persentage : "))

print(f"Name : {name} Type : {type(name)}")
print(f"Age : {age} Type : {type(age)}")
print(f"Percentage : {per} Type : {type(per)}")
# Out:
# Enter your name :  Het
# Enter your age :  18
# Enter your persentage :  90
# Name : Het Type : <class 'str'>
# Age : 18 Type : <class 'int'>
# Percentage : 90.0 Type : <class 'float'>

# %% [markdown]
# ### 05) WAP to print folowing message using custom separator and end.
# #### Ouutput : Python | Programming | Basics###

# %%
print("Python" ,"Programming", "Basics",sep=" | ",end="###")
# Out:
# Python | Programming | Basics###

# %% [markdown]
# ### 06) WAP to accept a value and display its value, type, and memory id.
# #### Input : hello
# #### Output :
# ##### Value: hello
# ##### Type: <class 'str'>
# ##### ID: 140712345678912

# %%
str = input("Enter something : ")
print(f"Valvu : {str}")
print(f"Type : {type(str)}")
print(f"ID : {id(str)}")
# Out:
# Enter something :  Hello
# Valvu : Hello
# Type : <class 'str'>
# ID : 1983439519984

# %% [markdown]
# ### 07) WAP to assign a value to a variable, print id, reassign a new value, and print id again.
# #### Output :
# ##### Original ID of a: 140712345678912
# ##### New ID of a: 140712345678960

# %%
a = 10
print(f"Original Id of a : {id(a)}")
a = 20
print(f"New Id of a : {id(a)}")
# Out:
# Original Id of a : 140732999181512
# New Id of a : 140732999181832

# %% [markdown]
# ### 08) WAP to print multiple lines using a single print().
# #### Output:
# ##### Welcome to Python
# ##### This is the second lab
# ##### Enjoy coding!

# %%
print("""
Welcome to Python
This is the second lab
Enjoy coding!
""")
# Out:
# Welcome to Python
# This is the second lab
# Enjoy coding!

# %% [markdown]
# ### 09) WAP to display following table of items with proper alignment.
# #### Output :
# | Sr No | Name        | Subject | Grade | Percentage |
# | ----: | ----------- | ------- | :---: | ---------: |
# |     1 | Nisha Patel | Math    |   A   |         92 |
# |     2 | Aarav Modi  | Science |   B+  |         85 |
# |     3 | Jiya Shah   | English |   A+  |         96 |

# %%
print(f"{"Sr No":<5}  {"Name":^15} {"Subject":^8} {"Grade":^6} {"Percentage"}")
print(f"{"1" : >5} {"Nisha Patel":^15} {"math":^8} {"A":^6} {"92":>10}")
print(f"{"2" : >5} {"Aarav Modi":^15} {"Science":^8} {"B+":^6} {"85":>10}")
print(f"{"3" : >5} {"Jiya Shah":^15} {"English":^8} {"A+":^6} {"96":>10}")
# Out:
# Sr No       Name       Subject  Grade  Percentage
#     1   Nisha Patel     math     A            92
#     2   Aarav Modi    Science    B+           85
#     3    Jiya Shah    English    A+           96

# %% [markdown]
# ### 10) WAP to accept a float number and display with 2 decimals, 3 decimals, and width 10.
# #### Input : 37.2567
# #### Output :
# ##### 2 decimals: 37.26
# ##### 3 decimals: 37.257
# ##### Width 10:      37.26

# %%
num = float(input("Enter a number : "))
print(f"2 decimals : {num:.2f}")
print(f"3 decimals : {num:.3f}")
print(f"Width 10 : {num:10.2f}")
# Out:
# Enter a number :  37.2657
# 2 decimals : 37.27
# 3 decimals : 37.266
# Width 10 :      37.27

# %% [markdown]
# ### 11) WAP to accept two integers and display sum, difference, and product using f-strings.
# #### Input : 12 8
# #### Output :
# ##### Sum = 20
# ##### Difference = 4
# ##### Product = 96

# %%
n1 = int(input("Enter a num 1 :"))
n2 = int(input("Enter a num 2 :"))
sum = n1+n2
diff = n1-n2
pro = n1*n2

print(f"Sum : {sum}")
print(f"Diffrence : {diff}")
print(f"Product : {pro}")
# Out:
# Enter a num 1 : 12
# Enter a num 2 : 8
# Sum : 20
# Diffrence : 4
# Product : 96

# %% [markdown]
# ### 12) WAP to accept date in dd mm yyyy format and display in multiple formats.
# #### Input : 01 12 2025
# #### Output :
# ##### 01/12/2025
# ##### 2025-12-01

# %%
day = int(input("Enter a Date : "))
month = int(input("Enter a Date : "))
year = int(input("Enter a Date : "))

print(day, month, year,sep="/")
print(year,month,day,sep="-")
# Out:
# Enter a Date :  01
# Enter a Date :  12
# Enter a Date :  2025
# 1/12/2025
# 2025-12-1

# %% [markdown]
# ### 13) WAP to calculate area and perimeter of a circle.

# %%
import math

r = float(input("Enter a radius : "))
area = math.pi * r * r
perimeter = 2 * math.pi * r
print(f"Area of circle : {area:.2f}")
print(f"perimeter of circle : {perimeter:.2f}")
# Out:
# Enter a radius :  3
# Area of circle : 28.27
# perimeter of circle : 18.85

# %% [markdown]
# ### 14) WAP to convert degree into Fahrenheit and vice versa.

# %%
d = float(input("Enter a degree : "))
f = float(input("Enter a fahrenheit : "))

print("Degree into fahrenheit : ",(d*9/5)+32)
print("fahrenheit into Degree : ",(f-32)*(5/9))
# Out:
# Enter a degree :  100
# Enter a fahrenheit :  212
# Degree into fahrenheit :  212.0
# fahrenheit into Degree :  100.0

# %% [markdown]
# ### 15) WAP to get the distance from user into kilometer, and convert it into meter, feet, inches and centimeter.

# %%
km = float(input("Enter a Kilometer : "))

print("Meter : ",km*1000)
print("Feet : ",km*3281)
print("inches : ",km*39370)
print("centimeter : ",km*100000)
# Out:
# Enter a Kilometer :  1
# Meter :  1000.0
# Feet :  3281.0
# inches :  39370.0
# centimeter :  100000.0
