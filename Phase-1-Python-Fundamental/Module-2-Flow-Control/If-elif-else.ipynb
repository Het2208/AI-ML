# %% [markdown]
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 3</b></center>
#     <center><b><h1>Roll No : 521</b></center>
#     <center><b><h1>Name : Kanasagara Het</b></center>
# <pre>

# %% [markdown]
# ### 01) WAP to check whether the given number is positive or negative.

# %%
n = int(input("Enter a number : "))
if n > 0:
    print("Positive")
elif n < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter a number :  0
# Zero

# %% [markdown]
# ### 02) WAP to check whether the given number is odd or even.

# %%
n = int(input("Enter a number : "))
if n % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter a number :  3
# Odd

# %% [markdown]
# ### 03) WAP to find out largest number from given two numbers using simple if and ternary operator.

# %%
n1 = int(input("Enter a number : "))
n2 = int(input("Enter a number : "))
print(f"{n1} is largest") if n1>n2 else print(f"{n2} is largest")
# Out:
# Enter a number :  4
# Enter a number :  5
# 5 is largest

# %% [markdown]
# ### 04) WAP to find out largest number from given three numbers.

# %%
n1 = int(input("Enter a number : "))
n2 = int(input("Enter a number : "))
n3 = int(input("Enter a number : "))
if n1 > n2 and n1 > n3 :
    print(f"{n1} is largest")
elif n2 > n1 and n2 > n3 :
    print(f"{n2} is largest")
else:
    print(f"{n3} is largest")
# Out:
# Enter a number :  3
# Enter a number :  4
# Enter a number :  5
# 5 is largest

# %% [markdown]
# ### 05) WAP to check whether the given year is leap year or not.
# #### [If a year can be divisible by 4 but not divisible by 100 then it is leap year but if it is divisible by 400 then it is leap year]

# %%
year = int(input("Enter a year : "))
if((year%4 == 0 and year%100 != 0) or (year%400)):
    print(f"{year} is leap year")
else:
    print(f"{year} is not leep year")
# Out:
# Enter a year :  2000
# 2000 is leap year

# %% [markdown]
# ### 06) WAP in python to display the name of the day according to the number given by the user.

# %%
n = int(input("Enter a number : "))
match(n):
    case 0:
        print("Sunday")
    case 1:
        print("Monday")
    case 2:
        print("Tuesday")
    case 3:
        print("Wednesday")
    case 4:
        print("Thursday")
    case 5:
        print("Friday")
    case 6:
        print("Satuday")
    case _:
        print("Invalide choice")
# Out:
# Enter a number :  38
# Invalide choice

# %% [markdown]
# ### 07) WAP to implement simple calculator which performs (add,sub,mul,div) of two no. based on user input.

# %%
ch = input("Enter a choice : [+ - * /]")
n1 = int(input("Enter a number : "))
n2 = int(input("Enter a number : "))

match(ch):
    case "+":
        print(f"{n1} + {n2} = {n1+n2}")
    case "+":
        print(f"{n1} - {n2} = {n1-n2}")
    case "+":
        print(f"{n1} * {n2} = {n1*n2}")
    case "+":
        print(f"{n1} / {n2} = {n1/n2}")
    case _:
        print("Invalid choice")
# Out:
# Enter a choice : [+ - * /] =
# Enter a number :  3
# Enter a number :  4
# Invalid choice

# %% [markdown]
# ### 08) WAP to read marks of five subjects. Calculate percentage and print class accordingly.
# #### Fail below 35
# #### Pass Class between 35 to 45
# #### Second Class
# #### between 45 to 60
# #### First Class between 60 to 70
# #### Distinction if more than 70

# %%
n1 = float(input("Enter a mark of subject 1 : "))
n2 = float(input("Enter a mark of subject 2 : "))
n3 = float(input("Enter a mark of subject 3 : "))
n4 = float(input("Enter a mark of subject 4 : "))
n5 = float(input("Enter a mark of subject 5 : "))

Total = n1+n2+n3+n4+n5
Percentage = (n1+n2+n3+n4+n5)/5

if Percentage > 70:
    print("Distinction")
elif Percentage >=60:
    print("First Class")
elif Percentage >=45:
    print("Second Class")
elif Percentage >= 35:
    print("Pass Class")
else:
    print("Fail")
# Out:
# Enter a mark of subject 1 :  6
# Enter a mark of subject 2 :  3
# Enter a mark of subject 3 :  2
# Enter a mark of subject 4 :  7
# Enter a mark of subject 5 :  8
# Fail

# %% [markdown]
# ### 09) WAP to find the second largest number among three user input numbers.

# %%
n1 = int(input("Enter a mark of subject 1 : "))
n2 = int(input("Enter a mark of subject 2 : "))
n3 = int(input("Enter a mark of subject 3 : "))

if (n1>n2 and n1<n3) or (n1>n3 and n1<n2):
    print(f"{n1} is second largest")
elif (n2>n1 and n2<n3) or (n2>n3 and n2<n1):
    print(f"{n2} is second largest")
else:
     print(f"{n3} is second largest")
# Out:
# Enter a mark of subject 1 :  4
# Enter a mark of subject 2 :  3
# Enter a mark of subject 3 :  5
# 4 is second largest

# %% [markdown]
# ### 10) WAP to calculate electricity bill based on following criteria. Which takes the unit from the user.
# #### a. First 1 to 50 units – Rs. 2.60/unit
# #### b. Next 50 to 100 units – Rs. 3.25/unit
# #### c. Next 100 to 200 units – Rs. 5.26/unit
# #### d. above 200 units – Rs. 8.45/unit

# %%
unit = int(input("Enter a unit of electricity"))
bill = 0
if unit > 1 and unit < 50:
    bill = unit * 2.60
elif unit > 50 and unit <100:
    bill = (50 * 2.60) + ((unit-50)*3.25)
elif unit > 100 and unit < 200:
    bill = (50 * 2.60) + (50*3.25) + ((unit-100)*5.26)
else: 
    bill = (50 * 2.60) + (50*3.25) + (100*5.26) + ((unit-200)*8.45)

print(f"Electricity = {bill}")
# Out:
# Enter a unit of electricity 400
# Electricity = 2508.5
