# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h2>Python Programming - 2301CS404</b></center>
# <center><b><h2>Lab - 13</b></center>
# <center><b><h3>Roll No.:521</b></center>
# <center><b><h3>Name:Het Kanasagara</b></center>
# <pre>

# %% [markdown]
# ### 01) WAP to create Calculator module which defines functions like add, sub,mul and div.
# ### Create another .py file that uses the functions available in Calculator module.

# %%
import calculator as c
print(c.add(1,2))
print(c.sub(3,1))
print(c.mul(2,4))
print(c.div(4,2))
# Out:
# 3
# 2
# 8
# 2

# %% [markdown]
# ### 02) WAP to pick a random character from a given String.

# %%
import random 
s = input("Enter a string : ")
print(random.choice(s))
# Out:
# Enter a string :  het
# e

# %% [markdown]
# ### 03) WAP to pick a random element from a given list.

# %%
l = ["het" , "meet" , "preet" , "rohan" , "ved"]
print(random.choice(l))
# Out:
# het

# %% [markdown]
# ### 04) WAP to roll a dice in such a way that every time you get the same number.

# %%
random.seed(11)
print(random.randint(1,6))
# Out:
# 4

# %% [markdown]
# ### 05) WAP to generate 3 random integers between 100 and 999 which is divisible by 5.

# %%
li = []
while len(li) != 3:
    r = random.randint(100,999)
    if r % 5 == 0:
        li.append(r)
print(li)
# Out:
# [620, 975, 290]

# %% [markdown]
# ### 06) WAP to generate 100 random lottery tickets and pick two lucky tickets from it and announce them as Winner and Runner up respectively.

# %%
li = [random.randint(100000 , 999999) for i in range(100)]
print(li)
print()
li = random.sample(li , 2)
print(f"Ticket number of winner : {li[0]}")
print(f"Ticket number of runner up : {li[1]}")
# Out:
# [928758, 258096, 135244, 752122, 584056, 887052, 713307, 503398, 102787, 624183, 163142, 288633, 167137, 683013, 914499, 776296, 477091, 436385, 790238, 606979, 921030, 133505, 641836, 405604, 630190, 967244, 986463, 765568, 817499, 645806, 880522, 657507, 282370, 722720, 917526, 908697, 273198, 217556, 737617, 556727, 346776, 800909, 561827, 674433, 910579, 368608, 924772, 850897, 929561, 856623, 347399, 372293, 612877, 670592, 331982, 994051, 708269, 732606, 623199, 374031, 137049, 312344, 725819, 849437, 155067, 700456, 570160, 288782, 440844, 259185, 737849, 118652, 738114, 620203, 945334, 555749, 628182, 563127, 858265, 375718, 998285, 937308, 132434, 176059, 219840, 286872, 696531, 770946, 669626, 707639, 930060, 857288, 349535, 753496, 253334, 156601, 426117, 546022, 144374, 829438]
#
# Ticket number of winner : 346776
# Ticket number of runner up : 375718

# %% [markdown]
# ### 07) WAP to print current date and time in Python.

# %%
import datetime
print(datetime.datetime.today())
# Out:
# 2026-03-18 12:59:22.938020

# %% [markdown]
# ### 08) Subtract a week (7 days) from a given date in Python.

# %%
givendate = datetime.date.today()
print(givendate - datetime.timedelta(7))
# Out:
# 2026-03-11

# %% [markdown]
# ### 09) WAP to Calculate number of days between two given dates.

# %%
date1 = datetime.datetime.today()
date2 = datetime.datetime(2024 , 12 , 1)
print(date1 - date2)
# Out:
# 472 days, 13:15:35.017142

# %% [markdown]
# ### 10) WAP to Find the day of the week of a given date.(i.e. wether it is sunday/monday/tuesday/etc.)

# %%
date2 = datetime.datetime(2000 , 12 , 1)
print(date2.strftime("%A"))
# Out:
# Friday
