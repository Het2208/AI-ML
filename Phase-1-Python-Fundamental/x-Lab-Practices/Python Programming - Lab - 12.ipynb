# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 12</b></center>
# <center><b><h3>Roll No : 521</b></center>
# <center><b><h3>Name : Kanasagara Het</b></center>
# <pre>

# %% [markdown]
# # Exception Handling

# %% [markdown]
# ### 01) WAP to handle following exceptions:
# 1. ZeroDivisionError
# 2. ValueError
# 3. TypeError
# #### Note: handle them using separate except blocks and also using single except block too.

# %%
try:
    n1 = int(input("Enter a number 1 : "))
    n2 = int(input("Enter a number 2 : "))
    ans = n1 / n2
except (ZeroDivisionError, ValueError , TypeError) as err:
    print(err)
else:
    print(ans)
# Out:
# Enter a number 1 :  10
# Enter a number 2 :  0
# division by zero

# %% [markdown]
# ### 02)  WAP to handle following exceptions:
# 1. IndexError
# 2. KeyError

# %%
l = [1]
try :
    idx = int(input("Enter a index of list :"))
    print(l[idx])
except IndexError as err:
    print(err)
# Out:
# Enter a index of list : 3
# list index out of range

# %%
d = {"1" : "one"}
try:
    key = int(input("Enter a key of dict :"))
    print(d[key])
except KeyError as err:
    print(type(err).__name__ , ":" , err)
# Out:
# Enter a key of dict : 4
# KeyError : 4

# %% [markdown]
# ### 03) WAP to handle following exceptions:
# 1. FileNotFoundError
# 2. ModuleNotFoundError

# %%
try:
    fp = open("file1234.txt" , "r")
except FileNotFoundError as err:
    print(err)
# Out:
# [Errno 2] No such file or directory: 'file1234.txt'

# %%
try:
    import xyx
except ModuleNotFoundError as err:
    print(err)
# Out:
# No module named 'xyx'

# %% [markdown]
# ### 04) WAP that handles all type of exceptions in a single except block in standard error message format.

# %%
try:
    print(10 / 0)
except Exception as err:
    print(type(err).__name__ , ":" , err)
# Out:
# ZeroDivisionError : division by zero

# %% [markdown]
# ### 05) WAP to demonstrate else  and finally block.

# %%
try:
    n1 = int(input("Enter a number 1 : "))
    n2 = int(input("Enter a number 2 : "))
    ans = n1 / n2
except (ZeroDivisionError, ValueError , TypeError) as err:
    print(err)
else:
    print(ans)
finally:
    print("Enter of Program!!")
# Out:
# Enter a number 1 :  10
# Enter a number 2 :  0
# division by zero
# Enter of Program!!

# %% [markdown]
# ### 06) WAP to create an udf divide(a,b) that handles ZeroDivisionError.

# %%
def divide(a,b):
    try:
        ans = n1 / n2
    except (ZeroDivisionError, ValueError , TypeError) as err:
        print(err)
    else:
        print(ans)
        
n1 = int(input("Enter a number 1 : "))
n2 = int(input("Enter a number 2 : "))
divide(n1,n2)
# Out:
# Enter a number 1 :  10
# Enter a number 2 :  0
# division by zero

# %% [markdown]
# ### 07) WAP to accept item prices and calculate total. Raise ValueError if price is negative, otherwise print the total bill amount.

# %%
try : 
    n = int(input("Enter a total number of items : "))
    total = 0
    for i in range(n):
        price = int(input("Enter a price"))
        if price < 0:
            raise ValueError("Price cannot be nagative")
        total += price
except Exception as err:
    print(type(err).__name__ , ":" ,err)
else:
    print(f"Total = {total}")
# Out:
# Enter a total number of items :  3
# Enter a price -1
# ValueError : Price cannot be nagative

# %% [markdown]
# ### 08) Create a short program that prompts the user for a list of grades separated by commas.
# #### Split the string into individual grades and use a list comprehension to convert each string to an integer.
# #### You should use a try statement to inform the user when the values they entered cannot be converted.

# %%
try : 
    grades = input("Enter a grades of subject(commaa separated) : ")
    li = grades.split(",")
    res = [int(i) for i in li]
except Exception as err:
    print(err)
# Out:
# Enter a grades of subject(commaa separated) :  10,11,12,A,B
# invalid literal for int() with base 10: 'A'

# %% [markdown]
# ### 09) Accept 5 subject marks (0-100). Use assert for validation.
#
# #### Sample Input (Error Case)
# #####  Enter marks: 110
#
# #### Sample Output (Error Case)
# ##### AssertionError: Marks should be between 0 and 100.
#
# #### Sample Input (Normal Case)
# ##### Valid marks entered
#
# #### Sample Output (Normal Case)
# ##### Average Marks displayed

# %%
try:
    Sum = 0
    for i in range(5):
        mark = int(input("Enter a mark : "))
        assert 0 <= mark <= 100 , "Mark should be between 0 and 100"
        Sum += mark
except AssertionError as err:
    print(err)
else:
    print(Sum / 5)
# Out:
# Enter a mark :  -1
# Mark should be between 0 and 100

# %% [markdown]
# ### 10) WAP that gets password from user. Password must have at least 8 characters and one digit.
# ### Raise WeakPasswordError if invalid, print the messsage "Correct" otherwise.

# %%
try:
    password = input("Enter a password :")
    assert len(password) > 8 , "invalid"
    Is_digit = False
    for i in password:
        if i.isdigit():
            Is_digit = True
    assert Is_digit == True , "invalid"
except AssertionError as err:
    print(err)
else:
    print("Correct")
# Out:
# Enter a password : asdasdfsghjijuytegrewrf
# invalid

# %% [markdown]
# ### 11) WAP to raise your custom Exception named NegativeNumberError with the error message : "Cannot calculate the square root of a negative number" :
# #### if the given number is negative.
# #### otherwise print the square root of the given number.

# %%
import math
class NegativeNumberError(Exception):
    pass

try : 
    n = int(input("Enter a number "))
    if n < 0:
        raise NegativeNumberError("Cannot calculate the square root of a negative number")
except Exception as err:
    print(type(err).__name__ , ":" ,err)
else:
    print(math.sqrt(n))
# Out:
# Enter a number  -1
# NegativeNumberError : Cannot calculate the square root of a negative number
